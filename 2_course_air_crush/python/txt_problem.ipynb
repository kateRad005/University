# %%
import numpy as np
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
df = pd.read_csv("newCrash.csv")

# %%
df
# Out:
#       Unnamed: 0        Date   Time  \
# 0              0  09/17/1908  17:18
# 1              1  07/12/1912  06:30
# 2              2  08/06/1913    NaN
# 3              3  09/09/1913  18:30
# 4              4  10/17/1913  10:30
# ...          ...         ...    ...
# 5263        5263  05/20/2009  06:30
# 5264        5264  05/26/2009    NaN
# 5265        5265  06/01/2009  00:15
# 5266        5266  06/07/2009  08:30
# 5267        5267  06/08/2009    NaN
#
#                                                Location  \
# 0                                   Fort Myer, Virginia
# 1                               AtlantiCity, New Jersey
# 2                    Victoria, British Columbia, Canada
# 3                                    Over the North Sea
# 4                            Near Johannisthal, Germany
# ...                                                 ...
# 5263                             Near Madiun, Indonesia
# 5264                  Near Isiro, DemocratiRepubliCongo
# ...

# %%
nums = ["1","2","3","4","5","6","7","8","9","0"]

# %%
modal_verbs = ["can", "could", "need", "may", "able", "must", "have", "should", "ought","shall", "will","would", "used","to"]

# %%
punctuation = [".", ",","'", "!", "?",")","("]

# %%
def stop_words(w:str):
    if w in modal_verbs:
        return False
    elif w in stopwords.words('english'):
        return False
    elif w in punctuation:
        return False
    for elem in nums:
        if elem in w:
            return False
    else:
        return True

# %%
dct = {}
ps = PorterStemmer()
for elem in df["Summary"]:
    if  type(elem)!= float:
        elem = elem.replace(",", "")
        sentences = sent_tokenize(elem)
        for sent in sentences:
            sent = sent.replace("!", "")
            sent = sent.replace("?", "")
            for word in word_tokenize(sent):
                w = word.lower()
                if stop_words(w):
                    if w in dct.keys():
                        dct[w] += 1
                    else:
                        dct[w] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 dct = {}
#       2 ps = PorterStemmer()
# ----> 3 for elem in df["Summary"]:
#       4     if  type(elem)!= float:
#       5         elem = elem.replace(",", "")
#
# NameError: name 'df' is not defined

# %%
sort_dct = sorted(dct.items(), key=lambda x: x[1], reverse=True)

# %%
len(sort_dct)

# %%
words = {"Word":list(dct.keys()),"Count":list(dct.values())}

# %%
words_df = pd.DataFrame(words)

# %%
words_df.to_csv("words_count.csv")

# %%
words_df = pd.read_csv("words_count.csv")
